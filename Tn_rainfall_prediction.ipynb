# %%
import pandas

# %%
data = pandas.read_csv('rainfall in india 1901-2015.csv')

# %%
data.head()
# Out:
#                  SUBDIVISION  YEAR   JAN  ...  Mar-May  Jun-Sep  Oct-Dec
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2  ...    560.3   1696.3    980.3
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  ...    458.3   2185.9    716.7
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  ...    236.1   1874.0    690.6
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4  ...    506.9   1977.6    571.0
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3  ...    309.7   1624.9    630.8
#
# [5 rows x 19 columns]

# %%
data_tn = data.query('SUBDIVISION == "TAMIL NADU" ')

# %%
data_tn.reset_index(inplace = True , drop = True)

# %%
data_tn.plot( x = 'YEAR'  , y ='ANNUAL')

# %%
data_tn
# Out:
#     SUBDIVISION  YEAR   JAN   FEB  ...  Jan-Feb  Mar-May  Jun-Sep  Oct-Dec
# 0    TAMIL NADU  1901  24.5  39.1  ...     63.6    131.6    350.1    415.0
# 1    TAMIL NADU  1902  67.2   9.8  ...     77.0    131.7    306.7    622.9
# 2    TAMIL NADU  1903  19.3   7.8  ...     27.1    148.4    456.5    531.9
# 3    TAMIL NADU  1904  35.2   0.1  ...     35.3    142.1    249.9    235.8
# 4    TAMIL NADU  1905   6.5   7.5  ...     14.0    165.7    264.1    377.2
# ..          ...   ...   ...   ...  ...      ...      ...      ...      ...
# 110  TAMIL NADU  2011   4.3  11.2  ...     15.5    132.8    306.4    471.8
# 111  TAMIL NADU  2012   3.0   0.1  ...      3.1     79.9    259.5    293.6
# 112  TAMIL NADU  2013   3.9  30.9  ...     34.8     92.2    321.5    293.4
# 113  TAMIL NADU  2014   7.4   6.1  ...     13.4    155.5    315.1    428.9
# 114  TAMIL NADU  2015   8.3   2.3  ...     10.6    242.8    285.9    665.3
#
# [115 rows x 19 columns]

# %%
import tensorflow as tf

# %%
from keras.optimizers import SGD

# %%
x = data_tn['YEAR']

# %%
y = data_tn[['JAN' ,'FEB' , 'MAR' , 'APR' , 'MAY' , 'JUN' , 'JUL' , 'AUG' , 'SEP' , 'OCT' , 'NOV' , 'DEC'] ]

# %%
model = tf.keras.models.Sequential([
                                    tf.keras.layers.Dense(1),
                                    tf.keras.layers.Dense (512 , activation = tf.keras.activations.relu) ,
                                    tf.keras.layers.Dense (64 , activation = tf.keras.activations.relu),
                                    tf.keras.layers.Dense( 12 , activation = tf.keras.activations.relu)
])

# %%
model.compile(  loss = 'mean_squared_error')

# %%
Y = y.to_numpy()

# %%
X = x.to_numpy()

# %%
history = model.fit( X , Y , epochs = 2000)
# Out:
# Epoch 1/2000
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 2/2000
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 3/2000
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 4/2000
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 5/2000
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 6/2000
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 7/2000
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 8/2000
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 9/2000
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 10/2000
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 11/2000
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 12/2000
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 13/2000
# ...

# %%
X
# Out:
# array([1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911,
#        1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922,
#        1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933,
#        1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944,
#        1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955,
#        1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966,
#        1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977,
#        1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988,
#        1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999,
#        2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015])

# %%
Y
# Out:
# array([[ 24.5,  39.1,  21.7, ..., 122.3, 212.3,  80.4],
#        [ 67.2,   9.8,  25.1, ..., 282.2, 174.9, 165.8],
#        [ 19.3,   7.8,   1.7, ..., 128.1, 200.5, 203.2],
#        ...,
#        [  3.9,  30.9,  30. , ..., 127.9, 112.3,  53.2],
#        [  7.4,   6.1,   8.1, ..., 252.2, 110.8,  66. ],
#        [  8.3,   2.3,  21.7, ..., 132.6, 379.8, 152.8]])
